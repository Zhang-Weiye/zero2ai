# %%
class Car():
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        
    def get_descriptive_name(self):
        long_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return long_name.title()
    
my_new_car = Car('audi', 'a4', 2016)
print(my_new_car.get_descriptive_name())
# Out:
# 2016 Audi A4

# %%
# 给属性指定默认值
class Car():
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
        
    def get_descriptive_name(self):
        long_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return long_name.title()
    
    def read_odometer(self):
        print(f"odometer is {self.odometer_reading}")
    
my_new_car = Car('audi', 'a4', 2016)
print(my_new_car.get_descriptive_name())
my_new_car.read_odometer()
# Out:
# 2016 Audi A4
# odometer is 0

# %%
 # 修改属性的值
my_new_car.odometer_reading = 23
my_new_car.read_odometer()
# Out:
# odometer is 23

# %%
# 通过方法修改属性的值
class Car():
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
        
    def get_descriptive_name(self):
        long_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return long_name.title()
    
    def read_odometer(self):
        print(f"odometer is {self.odometer_reading}")
        
    def update_odometer(self, mileage):
        self.odometer_reading = mileage
        
my_new_car = Car('audi', 'a4', 2016)
my_new_car.read_odometer()
my_new_car.update_odometer(100)
my_new_car.read_odometer()
# Out:
# odometer is 0
# odometer is 100

# %%
# 通过方法对属性的值进行递增
class Car():
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
        
    def get_descriptive_name(self):
        long_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return long_name.title()
    
    def read_odometer(self):
        print(f"odometer is {self.odometer_reading}")
        
    def update_odometer(self, mileage):
        self.odometer_reading = mileage
        
    def add_odometer(self, increment):
        self.odometer_reading += increment
        
my_new_car = Car('audi', 'a4', 2016)
my_new_car.read_odometer()
my_new_car.add_odometer(10)
my_new_car.read_odometer()
my_new_car.add_odometer(10)
my_new_car.read_odometer()
my_new_car.add_odometer(10)
my_new_car.read_odometer()
# Out:
# odometer is 0
# odometer is 10
# odometer is 20
# odometer is 30
