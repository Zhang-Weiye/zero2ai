# %%
# 利用for循环来遍历字典
user = {
    'username': 'efermi',
    'first': 'enrico',
    'last': 'fermi',
}

for key, value in user.items():
    print("\nKey: " + key)
    print("Value: " + value)
# Out:
# Key: username
# Value: efermi
#
# Key: first
# Value: enrico
#
# Key: last
# Value: fermi

# %%
# 遍历字典中的所有键
favorite_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'ruby',
    'phil': 'python',
}
for name in favorite_languages.keys():
    print(name.title())
# Out:
# Jen
# Sarah
# Edward
# Phil

# %%
# 遍历字典所有键时加入条件判断
favorite_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'ruby',
    'phil': 'python',
}
friends = ['sarah', 'edward']

for name in favorite_languages.keys():
    print(name.title(), end = '\n')
    
    if name in friends:
        print(" Hi " + name.title() + 
              "I see your favorite language is " +
              favorite_languages[name].title() + " .")
# Out:
# Jen
# Sarah
#  Hi SarahI see your favorite language is C .
# Edward
#  Hi EdwardI see your favorite language is Ruby .
# Phil

# %%
# 按顺序遍历字典中的所有键
favorite_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'ruby',
    'phil': 'python',
}

for name in sorted(favorite_languages.keys()):
    print(name.title() + ", thank you for taking the poll.")
# Out:
# Edward, thank you for taking the poll.
# Jen, thank you for taking the poll.
# Phil, thank you for taking the poll.
# Sarah, thank you for taking the poll.

# %%
# 遍历字典中的所有值
favorite_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'ruby',
    'phil': 'python',
}

print("The following languages have been mentioned:")
for language in favorite_languages.values():
    print(language.title())
# Out:
# The following languages have been mentioned:
# Python
# C
# Ruby
# Python

# %%
# 发现上面的例子打印出的语言存在重复，可利用集合 set()来处理
favorite_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'ruby',
    'phil': 'python',
}
print("The following languages have been mentioned:")
for language in set(favorite_languages.values()):
    print(language.title())
# Out:
# The following languages have been mentioned:
# C
# Ruby
# Python

# %%
# 习题6-5
rivers = {
    'nile': 'egypt',
    'huanghe': 'china',
    'panama': 'usa',
}

for key in rivers.keys():
    print("Key: ", key)
    
for value in rivers.values():
    print("Value: ", value)
# Out:
# Key:  nile
# Key:  huanghe
# Key:  panama
# Value:  egypt
# Value:  china
# Value:  usa
