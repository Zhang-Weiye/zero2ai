# %%
# 传递给函数列表
def greet_users(names):
    for name in names:
        msg = "Hello, " + name.title() + "!"
        print(msg)
        
usernames = ['hannah', 'ty', 'margot']
greet_users(usernames)
# Out:
# Hello, Hannah!
# Hello, Ty!
# Hello, Margot!

# %%
# 在函数中修改列表
unprinted_designs = ['iphone case', 'robot pendant', 'dodecahedron']
completed_models = []

while unprinted_designs:
    current_design = unprinted_designs.pop()
    
    print("Printing model: " + current_design)
    completed_models.append(current_design)
    
print("\nThe following models have been printed:")
for completed_model in completed_models:
    print(completed_model)
# Out:
# Printing model: dodecahedron
# Printing model: robot pendant
# Printing model: iphone case
#
# The following models have been printed:
# dodecahedron
# robot pendant
# iphone case

# %%
# 用两个函数来实现上方单元格的作用
def print_models(unprinted_designs, completed_models):
    
    while unprinted_designs:
        current_design = unprinted_designs.pop()
        
        print("Printing model: " + current_design)
        completed_models.append(current_design)
        
def show_completed_models(completed_models):
    print("\nThe following models have been printed:")
    
    for completed_model in completed_models:
        print(completed_model)
        
unprinted_designs = ['iphone case', 'robot pendant', 'dodecahedron']
completed_models = []

print_models(unprinted_designs, completed_models)
show_completed_models(completed_models)
# Out:
# Printing model: dodecahedron
# Printing model: robot pendant
# Printing model: iphone case
#
# The following models have been printed:
# dodecahedron
# robot pendant
# iphone case

# %%
# 禁止函数修改列表，可以通过向函数传递列表的副本而不是原件
def print_models(unprinted_designs, completed_models):
    
    while unprinted_designs:
        current_design = unprinted_designs.pop()
        
        print("Printing model: " + current_design)
        completed_models.append(current_design)
        
def show_completed_models(completed_models):
    print("\nThe following models have been printed:")
    
    for completed_model in completed_models:
        print(completed_model)
        
def show_origin_designs(unprinted_designs):
    print("\nHere is the original List:")
    
    for unprinted_design in unprinted_designs:
        print(unprinted_design)
        
unprinted_designs = ['iphone case', 'robot pendant', 'dodecahedron']
completed_models = []

print_models(unprinted_designs[:], completed_models)
show_completed_models(completed_models)
show_origin_designs(unprinted_designs)
# Out:
# Printing model: dodecahedron
# Printing model: robot pendant
# Printing model: iphone case
#
# The following models have been printed:
# dodecahedron
# robot pendant
# iphone case
#
# Here is the original List:
# iphone case
# robot pendant
# dodecahedron

# %%
# 习题8-9
magicians = ['liu qian', 'dong qing', 'zhao benshan']

def show_magicians(magicians):
    print("\nHere are the names of magicians:")
    for magician in magicians:
        print(magician, end=', ')
        
show_magicians(magicians)
# Out:
# Here are the names of magicians:
# liu qian, dong qing, zhao benshan,

# %%
# 习题8-10 错误示例，因为在for循环中修改列表了
def make_great(magicians):
    for magician in magicians:
        tmp = magician
        magicians.remove(tmp)
        tmp = "the Great" + tmp
        magicians.append(tmp)
        
magicians = ['liu qian', 'dong qing', 'zhao benshan']
make_great(magicians)
show_magicians(magicians)
# Out:
# Here are the names of magicians:
# dong qing, the Greatliu qian, the Greatthe Greatzhao benshan,

# %%
# 习题8-10 正确版1
def make_great_1(magicians):
    magicians[:] = ["the Great " + m for m in magicians]


# 正确版2
def make_great_2(magicians):
    for i in range(0, len(magicians)):
        magicians[i] = "the Great " + magicians[i]
        
magicians = ['liu qian', 'dong qing', 'zhao benshan']
make_great_1(magicians)
print(magicians)

players = ['antony', 'garnacho', 'hojlund']
make_great_2(players)
print(players)
# Out:
# ['the Great liu qian', 'the Great dong qing', 'the Great zhao benshan']
# ['the Great antony', 'the Great garnacho', 'the Great hojlund']

# %%
# 习题8-11
magicians = ['liu qian', 'dong qing', 'zhao benshan']
after_magicians = []

def make_great(magicians):
    return ["the Great " + m for m in magicians]

after_magicians = make_great(magicians[:])
show_magicians(magicians)
show_magicians(after_magicians)
# Out:
# Here are the names of magicians:
# liu qian, dong qing, zhao benshan,
# Here are the names of magicians:
# the Great liu qian, the Great dong qing, the Great zhao benshan,
