# %%
# 任意数量位置实参 在形参前加* 打包成元组
# 形参名*toppings中的星号让Python创建一个名为toppings的空元组，并将收到的所有值都封装到这个元组中
def make_pizza(*toppings):
    print("\nMaking a pizza with the following toppings:")
    for topping in toppings:
        print("- " + topping)
    
make_pizza('pepperoni')
make_pizza('mushrooms', 'green peppers', 'extra cheese')
# Out:
# Making a pizza with the following toppings:
# - pepperoni
#
# Making a pizza with the following toppings:
# - mushrooms
# - green peppers
# - extra cheese

# %%
# 结合位置实参和任意数量实参
# 如果要让函数接受不同类型的实参，必须在函数定义中将接纳任意数量实参的形参放在最后。
# Python先匹配位置实参和关键字实参，再将余下的实参都收集到最后一个形参中。
def make_pizza(size, *toppings):
    print("\nMaking a " + str(size)+ 
          "-inch pizza with the following toppings:")
    for topping in toppings:
        print("- " + topping)
        
make_pizza(12, 'pepperoni')
make_pizza(16, 'mushrooms', 'green peppers', 'extra cheese')
# Out:
# Making a 12-inch pizza with the following toppings:
# - pepperoni
#
# Making a 16-inch pizza with the following toppings:
# - mushrooms
# - green peppers
# - extra cheese

# %%
# 任意数量关键字实参 在形参前加** 打包成字典
# 有时候，需要接受任意数量的实参，但预先不知道传递给函数的会是什么样的信息。在这种情况下，可将函数编写成能够接受任意数量的键—值对——调用语句提供了多少就接受多少。
# 一个这样的示例是创建用户简介：你知道你将收到有关用户的信息，但不确定会是什么样的信息。
def build_profile(first, last, **user_info):
    profile = {}
    profile['first_name'] = first
    profile['last_name'] = last
    for key, value in user_info.items():
        profile[key] = value
    return profile

user_profile = build_profile('albert', 'einstein', 
                             location = 'princeton', field = 'physics')
print(user_profile)
# Out:
# {'first_name': 'albert', 'last_name': 'einstein', 'location': 'princeton', 'field': 'physics'}

# %% [markdown]
# ## 总结
#
# | 参数类型           | 定义与作用                                                                   | 示例代码                                                                 |
# |--------------------|------------------------------------------------------------------------------|--------------------------------------------------------------------------|
# | 位置实参           | 按照**定义顺序**传递，调用时**位置必须匹配**                                 | `def add(a, b):` <br> `add(3, 5)`  # a=3, b=5                           |
# | 关键字实参         | 调用时**指定参数名**，**顺序可乱**，提高可读性                               | `add(b=5, a=3)`  # 效果同上                                             |
# | 任意数量位置实参   | 在形参前加 `*`，接收**多余的位置实参**，打包成**元组**                       | `def foo(*args):` <br> `foo(1, 2, 3)`  # args=(1, 2, 3)                |
# | 任意数量关键字实参 | 在形参前加 `**`，接收**多余的关键字实参**，打包成**字典**                     | `def bar(**kwargs):` <br> `bar(x=1, y=2)`  # kwargs={'x':1, 'y':2}      |

# %%
# 习题8-12
def make_sandwich(*foods):
    print("\nYou have ordered the following foods:")
    for food in foods:
        print("- " + food)
        
make_sandwich('meat', 'egg', 'vegetables')
# Out:
# You have ordered the following foods:
# - meat
# - egg
# - vegetables

# %%
# 习题8-13
def build_profile(first_name, last_name, **user_info):
    profile = {}
    profile['first_name'] = first_name
    profile['last_name'] = last_name
    for key,value in user_info.items():
        profile[key] = value
    
    return profile
        
profile = build_profile('king', 'domdom', type = 'dog', age = 4, variety = 'golden retriever')
print(profile)
# Out:
# {'first_name': 'king', 'last_name': 'domdom', 'type': 'dog', 'age': 4, 'variety': 'golden retriever'}

# %%
# 习题8-14
def build_car_info(maker, model, **info):
    car_info = {}
    car_info['maker'] = maker
    car_info['model'] = model
    for key, value in info.items():
        car_info[key] = value
        
    return car_info

my_car = build_car_info('tesla', 'model_y', color='red', others='auto_drive')
print(my_car)
# Out:
# {'maker': 'tesla', 'model': 'model_y', 'color': 'red', 'others': 'auto_drive'}
