# %% [markdown]
# | 数字类型 | python表示 |
# | -------- | ---------- |
# | 整数     | int        |
# | 浮点数   | float      |

# %% [markdown]
# | 数学运算 | python表示|
# |---------|----------|
# |    加     |     +     |
# |     减    |      -    |
# |       乘  |      *    |
# |     除     |     /    |
# |     乘方     |    **     |
# |      取余    |     %    |
# |     整除     |     //    |

# %% [markdown]
# | 布尔数据 | python表示 |
# |---------|-----------|
# |   真    |     True   |
# |   假    |     False  |

# %% [markdown]
# |     关系运算符    |    python表示     |
# |---------|----------|
# |     大于    |      >    |
# |     小于    |      <    |
# |     等于    |      =    |
# |     大于等于    |     >=     |
# |     小于等于    |     <=     |
# |     不等于    |      !=     |

# %% [markdown]
# |    逻辑运算符    | python表示|
# |-|-|
# | 逻辑与| and|
# | 逻辑或| or|
# | 逻辑非| not|

# %% [markdown]
# **表1-2 可以应用于任意python序列的运算**
# | 运算名 | 运算符 | 解释                   |
# | ------ | ------ | ---------------------- |
# | 索引   | []     | 取序列中的某个元素     |
# | 连接   | +      | 将序列连接在一起       |
# | 重复   | *      | 重复N次连接            |
# | 成员   | in     | 询问序列中是否有某元素 |
# | 长度   | len    | 询问序列的元素个数     |
# | 切片   | [:]    | 取出序列的一部分       |

# %% [markdown]
# **表1-3 python列表提供的方法**
# | 方法名   | 用法                   | 解释                           |
# | -------- | ---------------------- | ------------------------------ |
# | append   | alist.append(item)     | 在列表末尾添加一个新元素        |
# | insert   | alist.insert(i, item)  | 在列表的第i个位置插入一个元素   |
# | pop      | alist.pop()            | 删除并返回列表中最后一个元素    |
# | pop      | alist.pop(i)           | 删除并返回列表中第i个位置的元素 |
# | sort     | alist.sort()           | 将列表元素排序                 |
# | reverse  | alist.reverse()        | 将列表元素倒序排列             |
# | del      | del alist[i]           | 删除列表中第i个位置的元素       |
# | index    | alist.index(item)      | 返回item第一次出现时的下标      |
# | count    | alist.count(item)      | 返回item在列表中出现的次数      |
# | remove   | alist.remove(item)     | 从列表中移除第一次出现的item    |

# %% [markdown]
# **表1-4  Python 字符串提供的方法**
#
# | 方法名   | 用法                        | 解释                                         |
# | -------- | --------------------------- | -------------------------------------------- |
# | center   | astring.center(w)           | 返回一个字符串，原字符串居中，使用空格填充新字符串，使其长度为w |
# | count    | astring.count(item)         | 返回item出现的次数                           |
# | ljust    | astring.ljust(w)            | 返回一个字符串，将原字符串靠左放置并填充空格至长度w |
# | rjust    | astring.rjust(w)            | 返回一个字符串，将原字符串靠右放置并填充空格至长度w |
# | lower    | astring.lower()             | 返回均为小写字母的字符串                     |
# | upper    | astring.upper()             | 返回均为大写字母的字符串                     |
# | title    | astring.title()             | 返回每个单词首字母大写的字符串               |
# | join     | '分隔符'.join(list)         | 用分隔符连接序列中的元素，生成新字符串       |
# | strip    | astring.strip()             | 去除字符串首尾的空白字符                     |
# | replace  | astring.replace(a, b)       | 替换字符串中的a为b                           |
# | find     | astring.find(item)          | 返回item第一次出现时的下标                   |
# | split    | astring.split(schar)        | 在schar位置将字符串分割成子串                |

# %%
name = '  David Beckham is my favorite player.   '
print(f"Original name: '{name}'")
print(f"len(name): {len(name)}")
print(f"name.count('a'): {name.count('a')}")
print(f"name.ljust(20, '*'): {name.ljust(20, '*')}")
print(f"name.rjust(20, '*'): {name.rjust(20, '*')}")
print(f"name.upper(): {name.upper()}")
print(f"name.lower(): {name.lower()}")
print(f"name.title(): {name.title()}")
print(f"name.center(20, '*'): {name.center(20, '*')}")
print(f"name.lstrip('D'): {name.lstrip('D')}")
print(f"name.rstrip('.'): {name.rstrip('.')}")
print(f"name.strip(): '{name.strip()}'")
print(f"name.replace('David', 'Cristiano'): {name.replace('David', 'Cristiano')}")
print(f"name.split(): {name.split()}")
print(f"name.find('my'): {name.find('my')}")
# Out:
# Original name: '  David Beckham is my favorite player.   '
# len(name): 41
# name.count('a'): 4
# name.ljust(20, '*'):   David Beckham is my favorite player.
# name.rjust(20, '*'):   David Beckham is my favorite player.
# name.upper():   DAVID BECKHAM IS MY FAVORITE PLAYER.
# name.lower():   david beckham is my favorite player.
# name.title():   David Beckham Is My Favorite Player.
# name.center(20, '*'):   David Beckham is my favorite player.
# name.lstrip('D'):   David Beckham is my favorite player.
# name.rstrip('.'):   David Beckham is my favorite player.
# name.strip(): 'David Beckham is my favorite player.'
# name.replace('David', 'Cristiano'):   Cristiano Beckham is my favorite player.
# name.split(): ['David', 'Beckham', 'is', 'my', 'favorite', 'player.']
# name.find('my'): 19

# %% [markdown]
# **表1-5  Python 集支持的运算**
#
# | 运算名 | 运算符         | 解释                                         |
# | ------ | -------------- | -------------------------------------------- |
# | 成员   | in             | 询问集中是否有某元素                         |
# | 长度   | len            | 获取集的元素个数                             |
# | 并集   | \|             | 返回一个包含aset与otherset所有元素的新集      |
# | 交集   | &              | 返回一个包含aset与otherset共有元素的新集      |
# | 差集   | -              | 返回一个集，其中包含只出现在aset中的元素      |
# | 子集   | <=             | 询问aset中的所有元素是否都在otherset中        |

# %% [markdown]
# **表1-6  Python 集提供的方法**
#
# | 方法名        | 用法                          | 解释                                         |
# | ------------- | ----------------------------- | -------------------------------------------- |
# | union         | aset.union(otherset)          | 返回一个包含aset和otherset所有元素的集        |
# | intersection  | aset.intersection(otherset)   | 返回一个仅包含两个集共有元素的集              |
# | difference    | aset.difference(otherset)     | 返回一个集，其中仅包含只出现在aset中的元素    |
# | issubset      | aset.issubset(otherset)       | 询问aset是否为otherset的子集                  |
# | add           | aset.add(item)                | 向aset添加一个元素                            |
# | remove        | aset.remove(item)             | 将item从aset中移除                            |
# | pop           | aset.pop()                    | 随机移除aset中的一个元素                      |
# | clear         | aset.clear()                  | 清除aset中的所有元素                          |

# %%
## Python 集合运算演示

# 创建集合
mySet = {False, 4.5, 3, 6, 'cat'}
print("mySet:", mySet)

yourSet = {99, 3, 100}
print("yourSet:", yourSet)

# 并集
print("mySet.union(yourSet):", mySet.union(yourSet))
print("mySet | yourSet:", mySet | yourSet)

# 交集
print("mySet.intersection(yourSet):", mySet.intersection(yourSet))
print("mySet & yourSet:", mySet & yourSet)

# 差集
print("mySet.difference(yourSet):", mySet.difference(yourSet))
print("mySet - yourSet:", mySet - yourSet)

# 子集判断
print("{3,100}.issubset(yourSet):", {3,100}.issubset(yourSet))
print("{3,100} <= yourSet:", {3,100} <= yourSet)

# 添加元素
mySet.add("house")
print("mySet after add('house'):", mySet)

# 移除元素
mySet.remove(4.5)
print("mySet after remove(4.5):", mySet)

# 随机弹出一个元素
popped = mySet.pop()
print("popped element:", popped)
print("mySet after pop():", mySet)

# 清空集合
mySet.clear()
print("mySet after clear():", mySet)
# Out:
# mySet: {False, 3, 4.5, 6, 'cat'}
# yourSet: {99, 3, 100}
# mySet.union(yourSet): {False, 3, 4.5, 99, 6, 100, 'cat'}
# mySet | yourSet: {False, 3, 4.5, 99, 6, 100, 'cat'}
# mySet.intersection(yourSet): {3}
# mySet & yourSet: {3}
# mySet.difference(yourSet): {False, 4.5, 6, 'cat'}
# mySet - yourSet: {False, 4.5, 6, 'cat'}
# {3,100}.issubset(yourSet): True
# {3,100} <= yourSet: True
# mySet after add('house'): {False, 3, 4.5, 'house', 6, 'cat'}
# mySet after remove(4.5): {False, 3, 'house', 6, 'cat'}
# popped element: False
# mySet after pop(): {3, 'house', 6, 'cat'}
# mySet after clear(): set()

# %% [markdown]
# **表1-7  Python 字典支持的运算**
#
# | 运算名 | 运算符           | 解释                                         |
# | ------ | ---------------- | -------------------------------------------- |
# | 索引   | myDict[k]        | 返回与k相关联的值，如果没有则报错            |
# | 成员   | key in adict     | 如果key在字典中，返回True，否则返回False     |
# | 删除   | del adict[key]   | 删除字典中指定key对应的键值对                |

# %%
phoneext = {'david': 1410, 'brad': 1137}
print("phoneext:", phoneext)

# 获取所有键
print("phoneext.keys():", phoneext.keys())
print("list(phoneext.keys()):", list(phoneext.keys()))

# 获取所有值
print("phoneext.values():", phoneext.values())
print("list(phoneext.values()):", list(phoneext.values()))

# 获取所有键值对
print("phoneext.items():", phoneext.items())
print("list(phoneext.items()):", list(phoneext.items()))

# 安全获取不存在的键
print('phoneext.get("kent"):', phoneext.get("kent"))
print('phoneext.get("kent", "NO ENTRY"):', phoneext.get("kent", "NO ENTRY"))
# Out:
# phoneext: {'david': 1410, 'brad': 1137}
# phoneext.keys(): dict_keys(['david', 'brad'])
# list(phoneext.keys()): ['david', 'brad']
# phoneext.values(): dict_values([1410, 1137])
# list(phoneext.values()): [1410, 1137]
# phoneext.items(): dict_items([('david', 1410), ('brad', 1137)])
# list(phoneext.items()): [('david', 1410), ('brad', 1137)]
# phoneext.get("kent"): None
# phoneext.get("kent", "NO ENTRY"): NO ENTRY

# %%
# print()函数的用法

# seq 控制分割符
print("A", "B", "C", sep="*")


# end 控制结尾符
print("Hello", end="***")
print("World")
# Out:
# A*B*C
# Hello***World

# %% [markdown]
# **表1-9  格式化字符串可用的类型声明**
#
# | 字符 | 输出格式                                                         |
# | ---- | ---------------------------------------------------------------- |
# | d、i | 整数                                                             |
# | u    | 无符号整数                                                       |
# | f    | m.dddd 格式的浮点数                                              |
# | e    | m.dddde+/−xx 格式的浮点数                                        |
# | E    | m.ddddE+/−xx 格式的浮点数                                        |
# | g    | 对指数小于−4 或者大于5的使用%e，否则使用%f                       |
# | c    | 单个字符                                                         |
# | s    | 字符串，或者任意可以通过str函数转换成字符串的Python数据对象      |
# | %    | 插入一个常量%符号                                                |

# %% [markdown]
# **表1-10  格式化修改符**
#
# | 修改符   | 例子         | 解释                                         |
# | -------- | ------------ | -------------------------------------------- |
# | 数字     | %20d         | 将值放在20个字符宽的区域中                   |
# | -        | %-20d        | 将值放在20个字符宽的区域中，并且左对齐       |
# | +        | %+20d        | 将值放在20个字符宽的区域中，并且右对齐       |
# | 0        | %020d        | 将值放在20个字符宽的区域中，并在前面补上0    |
# | .        | %20.2f       | 将值放在20个字符宽的区域中，并且保留小数点后2位 |
# | (name)   | %(name)d     | 从字典中获取name                             |

# %%
price = 24
item = "banana"

print("The %s costs %d cents" % (item, price))
print("The %+10s costs %5.2f cents" % (item, price))
print("The %+10s costs %10.2f cents" % (item, price))

itemdict = {"item": "banana", "cost": 24}
print("The %(item)s costs %(cost)7.1f cents" % itemdict)
# Out:
# The banana costs 24 cents
# The     banana costs 24.00 cents
# The     banana costs      24.00 cents
# The banana costs    24.0 cents

# %%
# 控制结构 while循环
count = 0
while count < 5:
    print("Count is:", count)
    count += 1
# Out:
# Count is: 0
# Count is: 1
# Count is: 2
# Count is: 3
# Count is: 4

# %%
# 控制结构 for循环
for i in range(5):
    print("i is:", i)
# Out:
# i is: 0
# i is: 1
# i is: 2
# i is: 3
# i is: 4

# %%
# 控制结构 if分支
if True:
    print("Condition is True")
else:
    print("Condition is False")
# Out:
# Condition is True

# %%
# 异常处理 try-except
import math
anumber = int(input("Please enter an integer: "))
try:
    print(math.sqrt(anumber))
except:
    print("Bad Value for square root")
# Out:
# 1.0

# %%
# 异常处理 raise
anumber = int(input("Please enter an integer: "))
if anumber < 0:
    raise ValueError("Negative value entered")
else:
    print(math.sqrt(anumber))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 4
#       2 anumber = int(input("Please enter an integer: "))
#       3 if anumber < 0:
# ----> 4     raise ValueError("Negative value entered")
#       5 else:
#       6     print(math.sqrt(anumber))
#
# ValueError: Negative value entered

# %%
# 函数-通过牛顿迭代法实现平方根函数
import math
def newton_sqrt(n: int) -> float:
    oldguess = n
    newguess = n/2
    while abs(oldguess - newguess) >= 1e-5:
        # print(oldguess, newguess)
        oldguess = newguess
        newguess = (newguess + n / newguess)/2
        # print(oldguess, newguess)
    return newguess

print(newton_sqrt(1.44))
print(newton_sqrt(1))
print(newton_sqrt(0))
# Out:
# 1.2
# 1.000000000000001
# 0.0

# %%
# 类-分数
class Fraction:
    
    def __init__(self, top, bottom):
        self.num = top
        self.den = bottom
        
    def show(self):
        print(self.num, "/", self.den)
        
    def __str__(self):
        return str(self.num) + "/" + str(self.den)
    
    def __add__(self, otherfraction):
        new_num = self.num*otherfraction.den + otherfraction.num*self.den
        new_den = self.den*otherfraction.den
        return Fraction(new_num, new_den)
    
    
f1 = Fraction(1, 4)
f2 = Fraction(1, 2)
print(f1 + f2)
# Out:
# 6/8

# %%
# 寻找最大公因数 Find the greatest common divisor
def gcd(m, n):
    # 2, 4; 34, 51; 2, 3; 1, 1; 144, 12
    if n == 0:
        return m
    else:
        print(f"m = {m}, n = {n}, m//n = {m//n}, m%n = {m%n}")
        return gcd(n, m%n)
        
print(gcd(34, 51))
print(gcd(144, 12))
print(gcd(166, 188))
print(gcd(53, 66))

# m = m1* m2* m3* a* b* c
# n = n1* n2* n3* a* b* c
# m%n + m//n * n = m
"""
第一步 m, n且保证 m > n
第二步 n, m-m//n * n
第三步 m-m//n * n , n % (m-m//n*n) = 
"""
# Out:
# m = 34, n = 51, m//n = 0, m%n = 34
# m = 51, n = 34, m//n = 1, m%n = 17
# m = 34, n = 17, m//n = 2, m%n = 0
# 17
# m = 144, n = 12, m//n = 12, m%n = 0
# 12
# m = 166, n = 188, m//n = 0, m%n = 166
# m = 188, n = 166, m//n = 1, m%n = 22
# m = 166, n = 22, m//n = 7, m%n = 12
# m = 22, n = 12, m//n = 1, m%n = 10
# m = 12, n = 10, m//n = 1, m%n = 2
# m = 10, n = 2, m//n = 5, m%n = 0
# 2
# m = 53, n = 66, m//n = 0, m%n = 53
# m = 66, n = 53, m//n = 1, m%n = 13
# m = 53, n = 13, m//n = 4, m%n = 1
# m = 13, n = 1, m//n = 13, m%n = 0
# 1
# '\n第一步 m, n且保证 m > n\n第二步 n, m-m//n * n\n第三步 m-m//n * n , n % (m-m//n*n) = \n'

# %%
class Fraction:
    
    def __init__(self, top, bottom):
        self.num = top
        self.den = bottom
        
    def show(self):
        print(self.num, "/", self.den)
        
    def __str__(self):
        return str(self.num) + "/" + str(self.den)
    

    
    def __add__(self, otherfraction):
        new_num = self.num*otherfraction.den + otherfraction.num*self.den
        new_den = self.den*otherfraction.den
        
        def gcd(m, n):
            if n == 0:
                return m
            return gcd(n, m%n)
        tmp = gcd(new_num, new_den)
        return Fraction(int(new_num/tmp), int(new_den/tmp))
    
    
f1 = Fraction(1, 4)
f2 = Fraction(1, 2)
print(f1 + f2)
# Out:
# 3/4

# %%
# 类 - 逻辑门
class LogicGate:
    
    def __init__(self, n):
        self.label = n
        self.output = None
        
    def getLabel(self):
        return self.label
    
    def getOutput(self):
        self.output = self.performGateLogic()
        return self.output

# %%
# 类- 双输入门
class BinaryGate(LogicGate):
    
    def __init__(self, n):
        super().__init__(n)
        
        self.pinA = None
        self.pinB = None
        
    def getPinA(self):
        """
        。如果输入没有与任何逻辑门相连接（None），那就和之前一样要求用户输入。
        如果有了连接，就访问该连接并且获取fromgate的输出值。
        这会触发fromgate处理其逻辑。该过程会一直持续，直到获取所有输入并且最终的输出值成为正在查询的逻辑门的输入。
        在某种意义上，这个电路反向工作，以获得所需的输入，再计算最后的结果。
        """
        if self.pinA == None:
            return int(input("Enter Pin A input for gate " +  
                   self.getLabel() + " -->"))
        else:
            return self.pinA.getFrom().getOutput()
        
    def getPinB(self):
        if self.pinB == None:
            return int(input("Enter Pin B input for gate " + 
                   self.getLabel() + "-->"))
        else:
            return self.pinB.getFrom().getOutput()
    def setNextPin(self, source):
        """
        在BinaryGate类中，逻辑门有两个输入，但连接器必须只连接其中一个。
        如果两个都能连接，那么默认选择pinA。
        如果pinA已经有了连接，就选择pinB。
        如果两个输入都已有连接，则无法连接逻辑门。
        """
        if self.pinA == None:
            self.pinA = source
        else:
            if self.pinB == None:
                self.pinB = source
            else:
                raise RuntimeError("Error: No empty pins")
        
# 类- 单输入门
class UnaryGate(LogicGate):
    
    def __init__(self, n):
        super().__init__(n)
        
        self.pinA = None
        
    def getPinA(self):
        if self.pinA == None:
            return int(input("Enter Pin input for gate " + 
                   self.getLabel() + "-->"))
        else:
            return self.pinA.getFrom().getOutput()
        
    def setNextPin(self, source):
        """
        在BinaryGate类中，逻辑门有两个输入，但连接器必须只连接其中一个。
        如果两个都能连接，那么默认选择pinA。
        如果pinA已经有了连接，就选择pinB。
        如果两个输入都已有连接，则无法连接逻辑门。
        """
        if self.pinA == None:
            self.pinA = source
        else:
            if self.pinB == None:
                self.pinB = source
            else:
                raise RuntimeError("Error: No empty pins")

# %%
# 类- 与门
class AndGate(BinaryGate):
    
    def __init__(self, n):
        super().__init__(n)
        
    def performGateLogic(self):
        a = self.getPinA()
        b = self.getPinB()
        if a == 1 and b == 1:
            return 1
        else:
            return 0
        
g1 = AndGate("G1")
g1.getOutput()
# Out:
# 1

# %%
# 类- 或门
class OrGate(BinaryGate):
    
    def __init__(self, n):
        super().__init__(n)
        
    def performGateLogic(self):
        a = self.getPinA()
        b = self.getPinB()
        if a == 0 and b == 0:
            return 0
        else:
            return 1
        
g2 = OrGate("G2")
g2.getOutput()
# Out:
# 0

# %%
# 类- 非门
class NotGate(UnaryGate):
    
    def __init__(self, n):
        super().__init__(n)
        
    def performGateLogic(self):
        a = self.getPinA()
        if a == 1:
            return 0
        else:
            return 1
        
g3 = NotGate("G3")
g3.getOutput()
# Out:
# 0

# %%
# 类- 连接器
class Connector:
    
    def __init__(self, fgate, tgate):
        self.fromgate = fgate
        self.togate = tgate
        
        tgate.setNextPin(self)
        
    def getFrom(self):
        return self.fromgate
    
    def getTo(self):
        return self.togate

# %%
g1 = AndGate("G1")
g2 = AndGate("G2")
g3 = OrGate("G3")
g4 = NotGate("G4")
c1 = Connector(g1, g3)
c2 = Connector(g2, g3)
c3 = Connector(g3, g4)

g4.getOutput()
# input 0 1 1 1
# Out:
# 0
